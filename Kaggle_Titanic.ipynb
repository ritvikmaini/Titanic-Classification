# %% [markdown]
# # Titanic — Machine Learning from Disaster
#
# Predict which passengers survived the Titanic using passenger manifest data.
#
# **Pipeline:** Feature engineering → Bayesian hyperparameter tuning → Six-model stacking ensemble → Threshold optimisation

# %%
import warnings; warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import re
import optuna
import shap
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import boxcox
from sklearn.cluster import KMeans
from sklearn.ensemble import (
    RandomForestClassifier, GradientBoostingClassifier,
    ExtraTreesClassifier, StackingClassifier
)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import (
    StratifiedKFold, RepeatedStratifiedKFold,
    cross_val_score, cross_val_predict
)
from sklearn.preprocessing import LabelEncoder
from catboost import CatBoostClassifier
import xgboost as xgb
import lightgbm as lgb

optuna.logging.set_verbosity(optuna.logging.WARNING)
sns.set_theme(style='whitegrid', palette='muted', font_scale=1.1)
SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
train = pd.read_csv('./data/train.csv')
test  = pd.read_csv('./data/test.csv')
test_ids  = test['PassengerId']
base_rate = train['Survived'].mean()

print(f'Train: {train.shape} | Test: {test.shape} | Survival rate: {base_rate:.1%}')
train.head()

# %%
train.isnull().sum()[train.isnull().sum() > 0].rename('missing')

# %%
# Survival rates by key categorical features
for col in ['Pclass', 'Sex', 'Embarked']:
    print(train[[col, 'Survived']].groupby(col).mean().round(3))
    print()

# %%
fig, axes = plt.subplots(1, 3, figsize=(14, 4))

# Pclass × Sex heatmap — the dominant interaction
sns.heatmap(
    train.pivot_table('Survived', 'Sex', 'Pclass', aggfunc='mean'),
    annot=True, fmt='.0%', cmap='RdYlGn', linewidths=0.5,
    vmin=0, vmax=1, ax=axes[0]
)
axes[0].set_title('Survival rate — Sex × Pclass')

# Age by survival
for s, lbl in [(0, 'Did not survive'), (1, 'Survived')]:
    train.loc[train.Survived == s, 'Age'].dropna().hist(
        ax=axes[1], alpha=0.6, bins=25, label=lbl
    )
axes[1].set_title('Age distribution')
axes[1].legend()

# Family size survival curve
train.assign(FamilySize=train.SibSp + train.Parch + 1)\
     .groupby('FamilySize')['Survived'].mean()\
     .plot(kind='bar', ax=axes[2], color='steelblue')
axes[2].set_title('Survival rate by Family Size')
axes[2].set_xlabel('Family size')

plt.tight_layout()
plt.show()

# %%
# Age × Pclass × Survival — shows class-dependent rescue patterns
g = sns.FacetGrid(train, col='Survived', row='Pclass', height=2.0, aspect=1.6)
g.map(plt.hist, 'Age', alpha=0.6, bins=20, color='steelblue')
g.add_legend()
g.figure.suptitle('Age by Pclass and Survival', y=1.02)
plt.show()

# %% [markdown]
# ## Feature Engineering
#
# Train and test are combined so all transformations are applied consistently.

# %%
all_data = pd.concat([train, test], sort=False).reset_index(drop=True)

# %%
# Title carries social standing and a strong survival prior;
# rare titles are grouped to avoid sparse categories.
all_data['Title'] = all_data['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False)
rare = {'Dr','Rev','Col','Major','Jonkheer','Don','Dona','Countess','Lady','Capt','Sir'}
all_data['Title'] = all_data['Title'].replace({'Mlle': 'Miss', 'Ms': 'Miss', 'Mme': 'Mrs'})
all_data['Title'] = all_data['Title'].apply(lambda t: 'Rare' if t in rare else t)

all_data['IsMarried'] = (all_data['Title'] == 'Mrs').astype(int)
all_data['NameLength'] = all_data['Name'].str.len()

# %%
# Impute missing ages using the median of each Title × Pclass group —
# more precise than a global median because age distributions differ by title and class.
for title in all_data['Title'].unique():
    for pc in [1, 2, 3]:
        known   = (all_data.Title == title) & (all_data.Pclass == pc) & all_data.Age.notna()
        missing = (all_data.Title == title) & (all_data.Pclass == pc) & all_data.Age.isna()
        if missing.any():
            med = all_data.loc[known, 'Age'].median()
            if not np.isnan(med):
                all_data.loc[missing, 'Age'] = med
all_data['Age'].fillna(all_data['Age'].median(), inplace=True)

all_data['Age_raw'] = all_data['Age'].copy()

# Box-Cox normalises the right skew so gradient-boosted models see cleaner splits.
age_bc, lam_age = boxcox(all_data['Age'] + 0.5)
all_data['Age'] = age_bc

all_data['AgeGroup'] = pd.cut(
    all_data['Age_raw'],
    bins=[0, 2, 12, 18, 35, 60, 120],
    labels=[0, 1, 2, 3, 4, 5]
).astype(int)

# %%
all_data['FamilySize'] = all_data['SibSp'] + all_data['Parch'] + 1
all_data['IsAlone']    = (all_data['FamilySize'] == 1).astype(int)

# Three-way split reflects the non-linear survival pattern:
# small families (2–4) survived best; large groups struggled to evacuate.
all_data['FamGroup'] = np.where(all_data['FamilySize'] == 1, 0,
                       np.where(all_data['FamilySize'] <= 4, 1, 2))

# %%
all_data['HasCabin']   = all_data['Cabin'].notna().astype(int)
all_data['_cabin_ltr'] = all_data['Cabin'].str[0].fillna('U')

# K-means clusters cabin letters by (survival rate, frequency) rather than
# a manual mapping — the grouping is learned from the data.
tr_mask = all_data['Survived'].notna()
cab_surv  = all_data.loc[tr_mask].groupby('_cabin_ltr')['Survived'].mean()
cab_count = all_data.loc[tr_mask].groupby('_cabin_ltr')['Survived'].count()
cab_X = np.column_stack([
    (cab_surv  - cab_surv.mean())  / cab_surv.std(),
    (cab_count - cab_count.mean()) / cab_count.std()
])
cab_map = dict(zip(cab_surv.index, KMeans(n_clusters=3, random_state=SEED, n_init=10).fit(cab_X).labels_))
all_data['DeckGroup'] = all_data['_cabin_ltr'].map(cab_map).fillna(-1).astype(int)

all_data['CabinNum'] = pd.to_numeric(
    all_data['Cabin'].str.extract(r'(\d+)', expand=False), errors='coerce'
)
all_data['CabinNumBin'] = (
    pd.cut(all_data['CabinNum'], bins=[0, 50, 100, 150, 999], labels=[0, 1, 2, 3])
    .astype('float').fillna(-1).astype(int)
)

# %%
# Fare: impute the single missing test value by class median, then Box-Cox.
all_data['Fare'] = all_data.groupby('Pclass')['Fare'].transform(lambda x: x.fillna(x.median()))
fare_bc, lam_fare = boxcox(all_data['Fare'] + 0.0001)
all_data['Fare'] = fare_bc

all_data['FareBin']       = pd.qcut(all_data['Fare'].rank(method='first'), 4, labels=False).astype(int)
all_data['TicketFreq']    = all_data['Ticket'].map(all_data['Ticket'].value_counts())
all_data['FarePerPerson'] = (all_data['Fare'] / all_data['TicketFreq']).fillna(0)

all_data['Embarked'].fillna('S', inplace=True)

# K-means ticket prefix grouping: same rationale as cabin grouping.
def raw_prefix(t):
    t = re.sub(r'[\.\ /]', '', str(t).upper())
    m = re.match(r'^([A-Z]+)', t)
    return m.group(1) if m else 'NUM'

all_data['_tprefix'] = all_data['Ticket'].apply(raw_prefix)
pfx_surv  = all_data.loc[tr_mask].groupby('_tprefix')['Survived'].mean()
pfx_count = all_data.loc[tr_mask].groupby('_tprefix')['Survived'].count()
pfx_X = np.column_stack([
    (pfx_surv  - pfx_surv.mean())  / (pfx_surv.std()  + 1e-8),
    (pfx_count - pfx_count.mean()) / (pfx_count.std() + 1e-8)
])
pfx_map = dict(zip(pfx_surv.index, KMeans(n_clusters=3, random_state=SEED, n_init=10).fit(pfx_X).labels_))
all_data['TicketGroup'] = all_data['_tprefix'].map(pfx_map).fillna(-1).astype(int)

all_data['IsWoman']        = (all_data['Sex'] == 'female').astype(int)
all_data['IsWomanOrChild'] = ((all_data['Sex'] == 'female') | (all_data['Age_raw'] < 12)).astype(int)
all_data['PclassSex']      = all_data['Pclass'].astype(str) + '_' + all_data['Sex']
all_data['AgeXPclass']     = all_data['Age'] * all_data['Pclass']
all_data['FareXPclass']    = all_data['Fare'] * all_data['Pclass']
all_data['Surname']        = all_data['Name'].str.split(',').str[0].str.strip().str.lower()

# %%
# Group survival rates: passengers sharing a ticket or surname+class had correlated fates.
# Leave-one-out encoding for the training set prevents the target from leaking into features
# during cross-validation — each passenger's rate excludes their own outcome.
tr = all_data[all_data['Survived'].notna()].copy()
te = all_data[all_data['Survived'].isna()].copy()

def loo_rate(df, group_cols):
    g_sum   = df.groupby(group_cols)['Survived'].transform('sum')
    g_count = df.groupby(group_cols)['Survived'].transform('count')
    rate = (g_sum - df['Survived']) / (g_count - 1).clip(lower=1)
    rate[g_count == 1] = base_rate
    return rate.fillna(base_rate)

tr['TicketSurvRate'] = loo_rate(tr, 'Ticket')
tr['FamilySurvRate'] = loo_rate(tr, ['Surname', 'Pclass'])

# Test passengers use full training means — no leakage since their labels are unknown.
ticket_mean = tr.groupby('Ticket')['Survived'].mean()
fam_mean    = tr.groupby(['Surname', 'Pclass'])['Survived'].mean()
te['TicketSurvRate'] = te['Ticket'].map(ticket_mean).fillna(base_rate)
te['FamilySurvRate'] = te.apply(lambda r: fam_mean.get((r['Surname'], r['Pclass']), base_rate), axis=1)

for df in [tr, te]:
    df['GroupSurvRate']   = df[['TicketSurvRate', 'FamilySurvRate']].max(axis=1)
    df['GroupSurvBinary'] = (df['GroupSurvRate'] > 0.5).astype(int)

all_data = pd.concat([tr, te], sort=False).reset_index(drop=True)

# %%
le = LabelEncoder()
for col in ['Sex', 'Embarked', 'Title', 'PclassSex']:
    all_data[col] = le.fit_transform(all_data[col].astype(str))

FEATURES = [
    'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked',
    'Title', 'FamilySize', 'IsAlone', 'FamGroup',
    'HasCabin', 'DeckGroup', 'CabinNumBin',
    'TicketFreq', 'FarePerPerson', 'TicketGroup',
    'AgeGroup', 'FareBin',
    'IsWoman', 'IsWomanOrChild', 'IsMarried', 'PclassSex', 'NameLength',
    'TicketSurvRate', 'FamilySurvRate', 'GroupSurvRate', 'GroupSurvBinary',
    'AgeXPclass', 'FareXPclass',
]

train_df = all_data[all_data['Survived'].notna()]
test_df  = all_data[all_data['Survived'].isna()]
X,     y   = train_df[FEATURES], train_df['Survived'].astype(int)
X_test     = test_df[FEATURES]

assert X.isna().sum().sum() == 0 and X_test.isna().sum().sum() == 0
print(f'{len(FEATURES)} features | train {X.shape} | test {X_test.shape}')

# %% [markdown]
# ## Hyperparameter Tuning
#
# Bayesian optimisation (Optuna, TPE sampler) over 60 trials each for LightGBM and XGBoost.
# More efficient than grid search and avoids the combinatorial explosion of many parameters.

# %%
cv5 = StratifiedKFold(n_splits=5, shuffle=True, random_state=SEED)

def lgb_objective(trial):
    params = dict(
        n_estimators      = trial.suggest_int('n_estimators', 200, 700),
        learning_rate     = trial.suggest_float('learning_rate', 0.01, 0.15, log=True),
        max_depth         = trial.suggest_int('max_depth', 3, 8),
        num_leaves        = trial.suggest_int('num_leaves', 15, 100),
        colsample_bytree  = trial.suggest_float('colsample_bytree', 0.5, 1.0),
        subsample         = trial.suggest_float('subsample', 0.5, 1.0),
        min_child_samples = trial.suggest_int('min_child_samples', 5, 40),
        reg_alpha         = trial.suggest_float('reg_alpha', 1e-3, 2.0, log=True),
        reg_lambda        = trial.suggest_float('reg_lambda', 1e-3, 2.0, log=True),
    )
    return cross_val_score(
        lgb.LGBMClassifier(**params, random_state=SEED, verbose=-1, n_jobs=-1),
        X, y, cv=cv5, scoring='accuracy'
    ).mean()

lgb_study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=SEED))
lgb_study.optimize(lgb_objective, n_trials=60)

def xgb_objective(trial):
    params = dict(
        n_estimators      = trial.suggest_int('n_estimators', 200, 700),
        learning_rate     = trial.suggest_float('learning_rate', 0.01, 0.15, log=True),
        max_depth         = trial.suggest_int('max_depth', 3, 8),
        colsample_bytree  = trial.suggest_float('colsample_bytree', 0.5, 1.0),
        subsample         = trial.suggest_float('subsample', 0.5, 1.0),
        min_child_weight  = trial.suggest_int('min_child_weight', 1, 10),
        gamma             = trial.suggest_float('gamma', 0.0, 0.5),
        reg_alpha         = trial.suggest_float('reg_alpha', 1e-3, 2.0, log=True),
        reg_lambda        = trial.suggest_float('reg_lambda', 1e-3, 2.0, log=True),
    )
    return cross_val_score(
        xgb.XGBClassifier(**params, eval_metric='logloss', random_state=SEED, verbosity=0, n_jobs=-1),
        X, y, cv=cv5, scoring='accuracy'
    ).mean()

xgb_study = optuna.create_study(direction='maximize', sampler=optuna.samplers.TPESampler(seed=SEED))
xgb_study.optimize(xgb_objective, n_trials=60)

print(f'LightGBM best 5-fold CV : {lgb_study.best_value:.4f}')
print(f'XGBoost  best 5-fold CV : {xgb_study.best_value:.4f}')

# %% [markdown]
# ## Stacking Ensemble
#
# Six base learners feed a Logistic Regression meta-learner trained on out-of-fold predictions.
# Stacking is preferred over soft voting because the meta-learner learns each model's relative
# strength on different subgroups rather than weighting them equally.

# %%
base_models = [
    ('rf',  RandomForestClassifier(
                n_estimators=500, max_depth=6, min_samples_split=4,
                min_samples_leaf=2, max_features='sqrt', random_state=SEED, n_jobs=-1)),
    ('gb',  GradientBoostingClassifier(
                n_estimators=300, learning_rate=0.05, max_depth=4,
                subsample=0.8, random_state=SEED)),
    ('et',  ExtraTreesClassifier(
                n_estimators=500, max_depth=7, min_samples_leaf=2,
                random_state=SEED, n_jobs=-1)),
    ('xgb', xgb.XGBClassifier(
                **xgb_study.best_params, eval_metric='logloss',
                random_state=SEED, verbosity=0, n_jobs=-1)),
    ('lgb', lgb.LGBMClassifier(
                **lgb_study.best_params, random_state=SEED, verbose=-1, n_jobs=-1)),
    ('cb',  CatBoostClassifier(
                iterations=400, learning_rate=0.05, depth=6,
                subsample=0.8, random_state=SEED, verbose=0)),
]

stacking = StackingClassifier(
    estimators=base_models,
    final_estimator=LogisticRegression(C=0.1, max_iter=1000, random_state=SEED),
    cv=cv5, n_jobs=-1
)

# %%
# RepeatedStratifiedKFold gives more stable accuracy estimates on this small dataset
# than a single 10-fold run: 25 folds reduce variance in the CV mean.
rskf = RepeatedStratifiedKFold(n_splits=5, n_repeats=5, random_state=SEED)

print(f'  {"Model":<8}  {"Accuracy":>8}  {"Std":>7}  {"Criterion (mean−std/2)":>24}')
print('  ' + '-' * 56)
for name, model in base_models:
    s = cross_val_score(model, X, y, cv=rskf, scoring='accuracy')
    print(f'  {name:<8}  {s.mean():>8.4f}  {s.std():>7.4f}  {s.mean() - s.std()/2:>24.4f}')

s = cross_val_score(stacking, X, y, cv=rskf, scoring='accuracy')
print(f'  {"stacking":<8}  {s.mean():>8.4f}  {s.std():>7.4f}  {s.mean() - s.std()/2:>24.4f}')

# %% [markdown]
# ## Pseudo-Labeling & Threshold Optimisation

# %%
stacking.fit(X, y)
test_proba = stacking.predict_proba(X_test)[:, 1]

# Only add pseudo-labels where the model is very confident (≥95%).
# Lower thresholds risk injecting noisy labels that hurt generalisation.
conf = 0.95
mask = (test_proba > conf) | (test_proba < (1 - conf))
print(f'Pseudo-labeled: {mask.sum()} / {len(test_proba)} test passengers')

X_aug = pd.concat([X, X_test[mask]], ignore_index=True)
y_aug = pd.concat([y, pd.Series((test_proba[mask] > 0.5).astype(int))], ignore_index=True)

stacking_aug = StackingClassifier(
    estimators=base_models,
    final_estimator=LogisticRegression(C=0.1, max_iter=1000, random_state=SEED),
    cv=cv5, n_jobs=-1
)
stacking_aug.fit(X_aug, y_aug)

# %%
# Tune the decision threshold on out-of-fold probabilities.
# The optimal threshold is not always 0.5 — class imbalance and probability
# calibration can shift it.
oof_proba = cross_val_predict(stacking, X, y, cv=cv5, method='predict_proba')[:, 1]

thresholds = np.arange(0.30, 0.71, 0.01)
accs = [(y == (oof_proba > t)).mean() for t in thresholds]
best_thresh, best_acc = thresholds[np.argmax(accs)], max(accs)

print(f'Optimal threshold : {best_thresh:.2f} | OOF accuracy : {best_acc:.4f}')

fig, ax = plt.subplots(figsize=(8, 3))
ax.plot(thresholds, accs, color='steelblue', linewidth=2)
ax.axvline(best_thresh, color='tomato', linestyle='--', label=f'Optimal = {best_thresh:.2f}')
ax.set_xlabel('Threshold'); ax.set_ylabel('OOF accuracy')
ax.set_title('Threshold optimisation')
ax.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Importance (SHAP)

# %%
lgb_fit   = lgb.LGBMClassifier(**lgb_study.best_params, random_state=SEED, verbose=-1).fit(X, y)
explainer = shap.TreeExplainer(lgb_fit)
sv        = explainer.shap_values(X)
sv        = sv[1] if isinstance(sv, list) else sv

importance = pd.Series(np.abs(sv).mean(axis=0), index=FEATURES).sort_values(ascending=False)

fig, ax = plt.subplots(figsize=(9, 8))
importance.head(20).sort_values().plot(kind='barh', ax=ax, color='steelblue')
ax.set_title('Top 20 features — mean |SHAP|', fontsize=13)
ax.set_xlabel('Mean |SHAP value|')
plt.tight_layout()
plt.savefig('shap_importance.png', dpi=150)
plt.show()

# %% [markdown]
# ## Submission

# %%
final_proba = stacking_aug.predict_proba(X_test)[:, 1]
final_preds = (final_proba > best_thresh).astype(int)

submission = pd.DataFrame({'PassengerId': test_ids, 'Survived': final_preds})
submission.to_csv('./submission.csv', index=False)

print(f'Survivors predicted : {final_preds.sum()} / {len(final_preds)}')
print(f'Survival rate       : {final_preds.mean():.1%}')
submission.head(10)
